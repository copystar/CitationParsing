# %% [markdown]
# # Selecting and counting journal names from a set of Web of Science records

# %% [markdown]
# For this particular example, I have a set of 5 records from Web of Science in BibTex format. But what works for 5 records should also work for 500.

# %% [markdown]
# ###But before that, thanks must be extended!
# Much thanks to Scott Moynes who was kind enough to unpuzzle the bibliographic.parsing module for me!
# https://gist.github.com/copystar/082ee2161f9c7a54c47a

# %% [markdown]
# ## Install the modules

# %% [markdown]
# apt-get install bibutils
# pip install zope.component
# pip install zope.schema
# pip install bibliograph.rendering
# pip install bibliograph.parsing

# %%
# This imports a bibtex file and parses the records into a list of python dictionaries

from bibliograph.parsing.parsers.bibtex import BibtexParser
bib = open('setof583.bib').read()
parser = BibtexParser()
source = parser.preprocess(bib)
result = parser.getEntries(source)
from pprint import pprint

# %%
# pprint(result)

# %%
# This uses list comprehension to go through each item of the list and get the values associated with 'journal'
journals = [ r.get('journal') for r in result]
print journals
# Out:
# ['COMPUTER NETWORKS', 'EXPERT SYSTEMS WITH APPLICATIONS', 'JOURNAL OF GREAT LAKES RESEARCH', 'GONDWANA RESEARCH', 'ANIMAL BEHAVIOUR', 'JOURNAL OF INTERNATIONAL MONEY AND FINANCE', 'INFORMATION PROCESSING LETTERS', 'SPECTROCHIMICA ACTA PART B-ATOMIC SPECTROSCOPY', 'NEUROBIOLOGY OF AGING', 'MEASUREMENT', 'BRAIN AND COGNITION', 'INTERNATIONAL JOURNAL OF THERMAL SCIENCES', 'JOURNAL OF MATERIALS PROCESSING TECHNOLOGY', 'WEAR', 'WEAR', 'JOURNAL OF SOUTH AMERICAN EARTH SCIENCES', 'JOURNAL OF ACCOUNTING AND PUBLIC POLICY', 'JOURNAL OF GEOCHEMICAL EXPLORATION', 'SURFACE SCIENCE', 'ACCIDENT ANALYSIS AND PREVENTION', 'JOURNAL OF NEUROLINGUISTICS', 'APPLIED THERMAL ENGINEERING', 'FEBS LETTERS', 'MARINE POLLUTION BULLETIN', 'JOURNAL OF GREAT LAKES RESEARCH', 'JOURNAL OF GREAT LAKES RESEARCH', 'PLACENTA', 'SOLID STATE COMMUNICATIONS', 'INTEGRATION-THE VLSI JOURNAL', 'JOURNAL OF MACROECONOMICS', 'APPLIED MATHEMATICAL MODELLING', 'CHEMICAL PHYSICS LETTERS', 'NEUROSCIENCE', 'CHEMICAL ENGINEERING JOURNAL', 'SIMULATION MODELLING PRACTICE AND THEORY', 'ENVIRONMENTAL POLLUTION', 'GAIT & POSTURE', 'SOLID STATE COMMUNICATIONS', 'EXPERT SYSTEMS WITH APPLICATIONS', 'JOURNAL OF PHOTOCHEMISTRY AND PHOTOBIOLOGY A-CHEMISTRY', 'MATERIALS SCIENCE AND ENGINEERING A-STRUCTURAL MATERIALS PROPERTIES    MICROSTRUCTURE AND PROCESSING', 'JOURNAL OF AFFECTIVE DISORDERS', 'SOCIAL SCIENCE & MEDICINE', 'INDUSTRIAL MARKETING MANAGEMENT', 'LITHOS', 'ACTA MATERIALIA', 'CHEMOSPHERE', 'ELECTROCHEMISTRY COMMUNICATIONS', 'ANIMAL BEHAVIOUR', 'RESOURCES CONSERVATION AND RECYCLING', 'JOURNAL OF MATERIALS PROCESSING TECHNOLOGY', 'PATTERN RECOGNITION', 'JOURNAL OF POWER SOURCES', 'MATHEMATICAL SOCIAL SCIENCES', 'INTERNATIONAL JOURNAL OF INDUSTRIAL ERGONOMICS', 'JOURNAL OF GREAT LAKES RESEARCH', 'COMPUTERS & OPERATIONS RESEARCH', 'HEALTH & PLACE', 'JOURNAL OF FUNCTIONAL ANALYSIS', 'AQUACULTURE', 'JOURNAL OF POWER SOURCES', 'COMPUTATIONAL AND THEORETICAL CHEMISTRY', 'CHEMOSPHERE', 'EXPERIMENTAL PARASITOLOGY', 'INTERNATIONAL JOURNAL OF MECHANICAL SCIENCES', 'STATISTICS & PROBABILITY LETTERS', 'ECOLOGICAL ENGINEERING', 'JOURNAL OF FLUIDS AND STRUCTURES', 'PERVASIVE AND MOBILE COMPUTING', 'INTERNATIONAL JOURNAL OF SOLIDS AND STRUCTURES', 'WEAR', 'JOURNAL OF ETHNOPHARMACOLOGY', 'AEU-INTERNATIONAL JOURNAL OF ELECTRONICS AND COMMUNICATIONS', 'PRECAMBRIAN RESEARCH', 'PROCEEDINGS OF THE COMBUSTION INSTITUTE', 'INTERNATIONAL JOURNAL OF IMPACT ENGINEERING', 'COMPUTERS & OPERATIONS RESEARCH', 'ECONOMICS & HUMAN BIOLOGY', 'EXPERT SYSTEMS WITH APPLICATIONS', 'FLORA', 'GAIT & POSTURE', 'JOURNAL OF MAGNETIC RESONANCE', 'SCRIPTA MATERIALIA', 'INFORMATION SCIENCES', 'CARBON', 'NEUROCOMPUTING', 'NEUROCOMPUTING', 'PATTERN RECOGNITION', 'SCIENCE OF THE TOTAL ENVIRONMENT', 'JOURNAL OF BUSINESS RESEARCH', 'EUROPEAN JOURNAL OF OPERATIONAL RESEARCH', 'BIOSENSORS & BIOELECTRONICS', 'INTERNATIONAL JOURNAL OF PRODUCTION ECONOMICS', 'ULTRASONICS', 'SCIENCE OF THE TOTAL ENVIRONMENT', 'SCIENCE OF THE TOTAL ENVIRONMENT', 'MATERIALS SCIENCE AND ENGINEERING A-STRUCTURAL MATERIALS PROPERTIES    MICROSTRUCTURE AND PROCESSING', 'ACCIDENT ANALYSIS AND PREVENTION', 'ACTA PSYCHOLOGICA', 'JOURNAL OF GREAT LAKES RESEARCH', 'COGNITION', 'ULTRASONICS', 'FUEL', 'JOURNAL OF MOLECULAR STRUCTURE', 'ANNALES MEDICO-PSYCHOLOGIQUES', 'ENVIRONMENTAL RESEARCH', 'MICROELECTRONICS RELIABILITY', 'OCEAN ENGINEERING', 'DEEP-SEA RESEARCH PART I-OCEANOGRAPHIC RESEARCH PAPERS', 'EXPERIMENTAL THERMAL AND FLUID SCIENCE', 'ADVANCES IN MATHEMATICS', 'INTERNATIONAL JOURNAL OF MASS SPECTROMETRY', 'TETRAHEDRON', 'NEUROCOMPUTING', 'MATERIALS SCIENCE AND ENGINEERING A-STRUCTURAL MATERIALS PROPERTIES    MICROSTRUCTURE AND PROCESSING', 'JOURNAL OF GREAT LAKES RESEARCH', 'JOURNAL OF TRANSPORT GEOGRAPHY', 'JOURNAL OF INTERNATIONAL FINANCIAL MARKETS INSTITUTIONS & MONEY', 'JOURNAL OF MICROBIOLOGICAL METHODS', 'BODY IMAGE', 'JOURNAL OF AIR TRANSPORT MANAGEMENT', 'JOURNAL OF MANUFACTURING SYSTEMS', 'ACCIDENT ANALYSIS AND PREVENTION', 'PROGRESS IN ORGANIC CO ...

# %%
from collections import Counter
journals_to_count = (word for word in journals if word[:1].isupper())
c = Counter(journals_to_count)
print c.most_common(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-9ff334764c14> in <module>()
#       1 from collections import Counter
#       2 journals_to_count = (word for word in journals if word[:1].isupper())
# ----> 3 c = Counter(journals_to_count)
#       4 print c.most_common(10)
#
# /usr/lib/python2.7/collections.pyc in __init__(self, iterable, **kwds)
#     448         '''
#     449         super(Counter, self).__init__()
# --> 450         self.update(iterable, **kwds)
#     451
#     452     def __missing__(self, key):
#
# /usr/lib/python2.7/collections.pyc in update(self, iterable, **kwds)
#     529             else:
#     530                 self_get = self.get
# --> 531                 for elem in iterable:
#     532                     self[elem] = self_get(elem, 0) + 1
#     533         if kwds:
#
# <ipython-input-54-9ff334764c14> in <genexpr>((word,))
#       1 from collections import Counter
# ----> 2 journals_to_count = (word for word in journals if word[:1].isupper())
#       3 c = Counter(journals_to_count)
#       4 print c.most_common(10)
#
# TypeError: 'NoneType' object has no attribute '__getitem__'
